# %% [markdown]
#  # - Encapsulation

# %% [markdown]
# # What is Encapsulation?
#
#   Encapsulation is the process of wrapping data and methods into a single unit (class) and restricting direct access to data by using private variables and public methods.
#
#    -  Encapsulation = Data Hiding + Data Protection

# %% [markdown]
# # 1. Public Members
#
# Public members can be accessed from anywhere.

# %%
class Student:

    def __init__(self):

        self.name = "Om"

student1 = Student()

print(student1.name)
# Out:
# Om

# %% [markdown]
#  - Public Variable

# %%
class Student:

    name = "Om"

# %% [markdown]
#   - Public Method

# %%
class Student:
  def display(self):
    print("Hello World")

# Accessible everywhere.

# %% [markdown]
#  # 2. Protected Members
#
#     Protected members are intended to be used only inside the class and its child classes.
#
#     Syntax
#
#         - _variable_name
#
#     Single underscore (_) is used.

# %%
# Examle  

class Student:
   def __init__(self):
        self._name = "Om"

student1 = Student()
print(student1._name)
# Out:
# Om

# %%
class Employee:
    def __init__(self):
        self._salary = 50000
        self._bonus = 5000
e1 = Employee()
print(e1._salary)
print(e1._bonus)
# Out:
# 50000
# 5000

# %% [markdown]
# Important Point
#
#         Even though we can access _name outside the class, we should not.
#
#         The underscore is a warning to programmers:
#
#         "This variable is meant for internal use."

# %% [markdown]
# # Protected Members with Inheritance

# %%
class person:
    def __init__(self):
        self._name = "Om"

class student(person):
    def display(self):
        print("Name:", self._name)

e1 = student()
e1.display()
# Out:
# Name: Om

# %% [markdown]
#    - Explanation
#       -  _name belongs to Person.
#       -  Student inherits Person.
#       -  Child class can access protected members.

# %% [markdown]
# # 3. Private Members
#
# Private members are used when data should not be accessed directly outside the class.
#
# Syntax
#
#    - __variable_name
#
# Double underscore (__) is used.

# %%
class Student:
   def __init__(self):
        self.__name = "Om"

student1 = Student()
print(student1.__name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 6
#       3         self.__name = "Om"
#       5 student1 = Student()
# ----> 6 print(student1.__name)
#
# AttributeError: 'Student' object has no attribute '__name'

# %% [markdown]
#   - Why Error Occurs?
#
#       Python hides private variables using a mechanism called Name Mangling.
#
#        Internally:
#
#            - self.__name
#
#       becomes
#
#            - self._Student__name
#
#       So Python cannot find __name directly.

# %% [markdown]
#   - Accessing Private Variables Using Methods

# %%
class Student:
   def __init__(self):
        self.__name = "Om"

   def display(self):
       print("Name:", self.__name)

student1 = Student()
student1.display()
# Out:
# Name: Om
