# %% [markdown]
# # OOP Interview - Top 50 Questions (Python)
#
# ## Class & Object
#
# ### 1. What is OOP?
#
# ### 2. What are the four pillars of OOP?
#
# ### 3. What is a Class?
#
# ### 4. What is an Object?
#
# ### 5. Difference between Class and Object?
#
# ### 6. Why is OOP used?
#
# ### 7. Can we create multiple objects from one class?
#
# ### 8. What is an instance of a class?
#
# ---
#
# ## Constructor & self
#
# ### 9. What is a Constructor?
#
# ### 10. What is the name of the constructor in Python?
#
# ### 11. Why is a constructor used?
#
# ### 12. Is constructor called automatically?
#
# ### 13. What is self?
#
# ### 14. Why is self required?
#
# ### 15. Difference between self and cls?
#
# ### 16. Can a constructor return a value?
#
# ### 17. What is a parameterized constructor?
#
# ### 18. What happens if constructor parameters are missing?
#
# ---
#
# ## Variables
#
# ### 19. What is an Instance Variable?
#
# ### 20. What is a Class Variable?
#
# ### 21. Difference between Instance Variable and Class Variable?
#
# ### 22. Which variable is shared among all objects?
#
# ### 23. Which variable is unique for each object?
#
# ---
#
# ## Methods
#
# ### 24. What is an Instance Method?
#
# ### 25. What is a Class Method?
#
# ### 26. What is a Static Method?
#
# ### 27. What is @classmethod?
#
# ### 28. What is @staticmethod?
#
# ### 29. Difference between Instance, Class and Static Methods?
#
# ### 30. Which method can access instance variables?
#
# ### 31. Which method can access class variables?
#
# ---
#
# ## Encapsulation
#
# ### 32. What is Encapsulation?
#
# ### 33. What is Data Hiding?
#
# ### 34. What are Access Modifiers in Python?
#
# ### 35. What is a Public Variable?
#
# ### 36. What is a Protected Variable?
#
# ### 37. What is a Private Variable?
#
# ### 38. What is Name Mangling?
#
# ### 39. Why use Getter and Setter methods?
#
# ### 40. Difference between Public, Protected and Private members?
#
# ---
#
# ## Inheritance
#
# ### 41. What is Inheritance?
#
# ### 42. Why is Inheritance used?
#
# ### 43. What is a Parent Class?
#
# ### 44. What is a Child Class?
#
# ### 45. What are the Types of Inheritance?
#
# ### 46. What is Single Inheritance?
#
# ### 47. What is Multiple Inheritance?
#
# ### 48. What is Multilevel Inheritance?
#
# ### 49. What is Hierarchical Inheritance?
#
# ### 50. What is Hybrid Inheritance?
#
# ---
#
# ## Polymorphism
#
# ### 51. What is Polymorphism?
#
# ### 52. What is Method Overriding?
#
# ### 53. What is Runtime Polymorphism?
#
# ### 54. What is Method Overloading?
#
# ### 55. Does Python support Method Overloading?
#
# ### 56. What is Operator Overloading?
#
# ### 57. What is Duck Typing?
#
# ### 58. Difference between Overloading and Overriding?
#
# ---
#
# ## Abstraction
#
# ### 59. What is Abstraction?
#
# ### 60. Why is Abstraction used?
#
# ### 61. What is an Abstract Class?
#
# ### 62. What is an Abstract Method?
#
# ### 63. What is the ABC Module?
#
# ### 64. Can we create an object of an Abstract Class?
#
# ### 65. Difference between Abstraction and Encapsulation?
#
# ---
#
# ## Most Frequently Asked Questions
#
# ### 66. Difference between Class and Object?
#
# ### 67. Difference between Instance and Class Variables?
#
# ### 68. Difference between Instance Method and Static Method?
#
# ### 69. Difference between Class Method and Static Method?
#
# ### 70. Difference between Inheritance and Composition?
#
# ### 71. Difference between Encapsulation and Abstraction?
#
# ### 72. Difference between Overloading and Overriding?
#
# ### 73. Difference between Compile-Time and Runtime Polymorphism?
#
# ### 74. Why is OOP important in real-world applications?
#
# ### 75. Which OOP concepts are used most in Python projects?
#
# ---
#
# # Top 10 Most Important Questions
#
# 1. What is OOP?
# 2. What are the four pillars of OOP?
# 3. Difference between Class and Object?
# 4. What is a Constructor?
# 5. What is Encapsulation?
# 6. What is Inheritance?
# 7. What is Polymorphism?
# 8. What is Abstraction?
# 9. Difference between Abstraction and Encapsulation?
# 10. Difference between Overloading and Overriding?
#
# ---
#
# # One-Line Revision
#
# OOP is based on four pillars:
#
# 1. Encapsulation
# 2. Inheritance
# 3. Polymorphism
# 4. Abstraction
#
# These concepts help build reusable, maintainable, and scalable software systems.
