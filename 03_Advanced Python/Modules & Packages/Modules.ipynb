# %% [markdown]
# # Modules & Packages in Python

# %% [markdown]
# 1. What is a Module?
#  - creating modules
#  -  importing modules
#  - using functions from modules

# %%
import math

# %% [markdown]
# 2. Built-in Modules
#  - math
#  -random
#  - os
#   -datetime

# %% [markdown]
# # 3. User-defined Modules
#
# Creating your own .py files.

# %% [markdown]
# 4. import Statement

# %%
import My_Module

# %% [markdown]
# 5. from ... import ...

# %%
from My_Module import add, multiply

print("Addition of the numbers : ", add(5, 6))

print("Product of the numbers : ", multiply(5, 6))
# Out:
# Addition of the numbers :  11
# Product of the numbers :  30

# %% [markdown]
# 6. Aliasing

# %%
import pandas as pd

import numpy as np

# %% [markdown]
# # dir() Function
#
# Used to check module contents.
