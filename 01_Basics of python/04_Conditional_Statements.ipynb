# %% [markdown]
# # Conditional Statements in Python
#
# Conditional statements are used to make decisions in a program. They execute different blocks of code depending on whether a condition is True or False.
#
# Conditional statements help programs:
#
# * Make decisions
# * Validate user input
# * Perform authentication
# * Calculate grades
# * Build menu-driven applications
#
# ---
#
# ## 1. if Statement
#
# The `if` statement executes a block of code only when the specified condition is True.
#
# ### Syntax
#
# ```python
# if condition:
#     # code block
# ```
#
# ### Example

# %%
age = 18 

if age >= 18 :
   print("Eligibal to vote ")
# Out:
# Eligibal to vote

# %% [markdown]
# ---
#
# ## 2. if-else Statement
#
# The `if-else` statement is used when there are two possible outcomes. One block executes when the condition is True and another block executes when the condition is False.
#
# ### Syntax
#
# ```python
# if condition:
#     # True block
# else:
#     # False block
# ```
#
# ### Example

# %%
num = 33 

if num % 2 == 0 :
  print("Number is Even")
else:
  print("Number is odd")
# Out:
# Number is odd

# %% [markdown]
# ---
#
# ## 3. if-elif-else Statement
#
# The `if-elif-else` statement is used to check multiple conditions. Python evaluates the conditions from top to bottom and executes the first matching block.
#
# ### Syntax
#
# ```python
# if condition1:
#     # block 1
# elif condition2:
#     # block 2
# else:
#     # default block
# ```
#
# ### Example

# %%
marks = 85

if marks >= 90:
  print("Grade A")
elif marks >= 60:
  print("Grade B")
else:
  print("Grade C")
# Out:
# Grade B

# %% [markdown]
# --
#
# ## 4. Nested if Statement
#
# A Nested `if` statement means placing one `if` statement inside another `if` statement. It is useful when one condition depends on another.
#
# ### Syntax
#
# ```python
# if condition1:
#     if condition2:
#         # code block
# ```
#
# ### Example

# %%
age = 19 
liciens = True

if age >= 18:
  if liciens:
    print("Eligibale for the Driving!")
# Out:
# Eligibale for the Driving!

# %% [markdown]
# ---
#
# ## 5. One-Line if-else Statement
#
# Python provides a shorthand way to write simple conditional statements in a single line.
#
# ### Syntax
#
# ```python
# value_if_true if condition else value_if_false
# ```
#
# ### Example

# %%
num = 19

print("Even") if num % 2 == 0 else print("Odd")
# Out:
# Odd

# %% [markdown]
# ---
#
# ## 6. Logical Operators with Conditional Statements
#
# Logical operators are used to combine multiple conditions.
#
# ### AND Operator
#
# Returns True only when all conditions are True.
#
# ```python
# if age >= 18 and citizen:
#     print("Eligible")
# ```
#
# ### OR Operator
#
# Returns True if at least one condition is True.
#
# ```python
# if day == "Saturday" or day == "Sunday":
#     print("Weekend")
# ```
#
# ### NOT Operator
#
# Reverses the result of a condition.
#
# ```python
# if not is_raining:
#     print("Go Outside")
# ```
#
# ---
#
# ## Applications of Conditional Statements
#
# * Voting Eligibility Checker
# * Login Authentication System
# * Grade Calculator
# * ATM Machine
# * Banking Applications
# * Student Result Management System
# * E-commerce Discount Calculator
#
# ---
#
# ## Key Points
#
# * `if` executes code when a condition is True.
# * `if-else` handles two possible outcomes.
# * `if-elif-else` handles multiple conditions.
# * Nested `if` is used for complex decision-making.
# * Logical operators help combine multiple conditions.
# * Conditional statements are the foundation of decision-making in Python.
#
# ---
#
# ## Summary
#
# Conditional statements allow Python programs to make decisions based on different conditions. They improve the flexibility and intelligence of applications by controlling the flow of execution according to user input or program requirements.
